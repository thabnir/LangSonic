# %%
from datasets import load_dataset
from torch.utils.data import DataLoader

# %%
cv_13 = load_dataset("mozilla-foundation/common_voice_13_0", "as", split="train", token="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")
dataloader = DataLoader(cv_13, batch_size=32)
# Out:
# Using the latest cached version of the module from /Users/thabnir/.cache/huggingface/modules/datasets_modules/datasets/mozilla-foundation--common_voice_13_0/2506e9a8950f5807ceae08c2920e814222909fd7f477b74f5d225802e9f04055 (last modified on Sun Oct 22 11:46:20 2023) since it couldn't be found locally at mozilla-foundation/common_voice_13_0., or remotely on the Hugging Face Hub.
# ...
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# /Users/thabnir/maisproj/data2.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/thabnir/maisproj/data2.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> cv_13 = load_dataset("mozilla-foundation/common_voice_13_0", "as", split="train")
#       <a href='vscode-notebook-cell:/Users/thabnir/maisproj/data2.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> dataloader = DataLoader(cv_13, batch_size=32)
#
# ...
